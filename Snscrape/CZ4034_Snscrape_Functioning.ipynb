# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.3

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
# cities, keywords, & other constants
cities = ["Delhi", "Beijing", "Singapore", 
          "Washington DC", "Moscow", "London", 
          "Ottawa", "Canberra", "Mexico City", 
          "Brasilia", "Cape Town"]

keywords = ["#Trump2020", "#Vote", "#vote", "#Election2020", "#Biden", "#VoteBlueToSaveAmerica", 
            "#trump2020", "#VoteTrumpOut", "#election2020", "#trump", "#biden", "#2020election", 
            "#November3rd", "#NovemberIsComing", "#donaldtrump", "#MyPresident", "#Elections_2020", 
            "#2020elections", "#USElections", "#bluewave2020", "ballot", "mailin", "mail-in", "mail in", 
            "donaldtrump", "donaldjtrump","donald j trump", "donald trump", "don trump", "joe biden", 
            "joebiden", "biden", "mike pence", "michael pence", "mikepence", "michaelpence", "kamala harris", 
            "kamala", "kamalaharris", "trump", "PresidentTrump", "MAGA", "trump2020", "Sleepy Joe", "Sleepyjoe", 
            "HidenBiden", "CreepyJoeBiden", "NeverBiden", "BidenUkraineScandal", "DumpTrump", "NeverTrump", "VoteRed", "VoteBlue"]

num_tweets = 1000

# %%
df = pd.DataFrame()
for word in keywords:
    df = df.append(pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
        '{} near:"Moscow" within:1000km lang:en since:2020-11-15'.format(word)).get_items(), 100))) #[["user", "content", "url", "date"]]

df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/TRUMPGOD303/status/1357767...
# 1  https://twitter.com/renetiemo/status/133849217...
# 2  https://twitter.com/TwiggyjameJames/status/133...
# 0  https://twitter.com/Vision_911_bg/status/13596...
# 1  https://twitter.com/elman_murad/status/1358385...
#
#                        date  \
# 0 2021-02-05 19:05:47+00:00
# 1 2020-12-14 14:32:56+00:00
# 2 2020-11-26 22:19:47+00:00
# 0 2021-02-10 22:19:13+00:00
# 1 2021-02-07 12:03:51+00:00
#
#                                              content  \
# 0  So...Time Magazine is now admitting that there...
# 1  You need any help leaving Donnie?? #trump2020 ...
# 2       @realTrumpForce Kefalonia Greece. #Trump2020
# 0  The biggest #theft In the #history of mankind ...
# 1  50 years ago today:🇨🇭women were granted the ri...
#
#                                      renderedContent                   id  \
# 0  So...Time Magazine is now admitting that there...  1357767391975903232
# 1  You need any help leaving Donnie?? #trump2020 ...  1338492173076017153
# 2       @realTrumpForce Kefalonia Greece. #Trump2020  1332086676143939584
# 0  The biggest #theft In the #history of mankind ...  1359628012505993218
# 1  50 years ago today:🇨🇭women were granted the ri...  1358385987131473921
#
#                                                 user  \
# 0  {'username': 'TRUMPGOD303', 'displayname': 'Ru...
# 1  {'username': 'renetiemo', 'displayname': '🇳🇱🅤🅟...
# 2  {'username': 'TwiggyjameJames', 'displayname':...
# 0  {'username': 'Vision_911_bg', 'displayname': '...
# 1  {'username': 'elman_murad', 'displayname': 'El...
#
#                                             outlinks  \
# 0  [https://time.com/5936036/secret-2020-election...
# 1                                                 []
# 2                                                 []
# 0                               [http://1844.911.bg]
# 1  [https://twitter.com/ParmelinG/status/13583277...
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0  [https://t.co/NfHimuargb]           0             0  ...           0
# 1                         []           0             0  ...           0
# 2                         []           0             0  ...           0
# 0  [https://t.co/JZyn9NUxhQ]           0             0  ...           1
# 1  [https://t.co/RTtQyR09HA]           0             0  ...           0
#
#         conversationId  lang  \
# 0  1357767391975903232    en
# 1  1338492173076017153    en
# 2  1330336178072137729    en
# 0  1359628012505993218    en
# 1  1358385987131473921    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel  \
# 0   http://twitter.com/download/iphone   Twitter for iPhone
# 1   http://twitter.com/download/iphone   Twitter for iPhone
# 2   http://twitter.com/download/iphone   Twitter for iPhone
# 0           https://mobile.twitter.com      Twitter Web App
# 1  http://twitter.com/download/android  Twitter for Android
#
#                                                media retweetedTweet  \
# 0                                               None           None
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...           None
# 2                                               None           None
# 0  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...           None
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...           None
#
#                                          quotedTweet  \
# 0                                               None
# 1                                               None
# 2                                               None
# 0                                               None
# 1  {'url': 'https://twitter.com/ParmelinG/status/...
#
#                                       mentionedUsers
# 0                                               None
# 1                                               None
# 2  [{'username': 'realTrumpForce', 'displayname':...
# 0                                               None
# 1                                               None
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (2116, 21)

# %%
df[["user", "content", "url", "date"]].to_csv('snscrape_Russia.csv', index = False)
