# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.3

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
# cities, keywords, & other constants
cities = ["Delhi", "Beijing", "Singapore", 
          "Washington DC", "Moscow", "London", 
          "Ottawa", "Canberra", "Mexico City", 
          "Brasilia", "Cape Town"]

keywords = ["#Trump2020", "#Vote", "#vote", "#Election2020", "#Biden", "#VoteBlueToSaveAmerica", 
            "#trump2020", "#VoteTrumpOut", "#election2020", "#trump", "#biden", "#2020election", 
            "#November3rd", "#NovemberIsComing", "#donaldtrump", "#MyPresident", "#Elections_2020", 
            "#2020elections", "#USElections", "#bluewave2020", "ballot", "mailin", "mail-in", "mail in", 
            "donaldtrump", "donaldjtrump","donald j trump", "donald trump", "don trump", "joe biden", 
            "joebiden", "biden", "mike pence", "michael pence", "mikepence", "michaelpence", "kamala harris", 
            "kamala", "kamalaharris", "trump", "PresidentTrump", "MAGA", "trump2020", "Sleepy Joe", "Sleepyjoe", 
            "HidenBiden", "CreepyJoeBiden", "NeverBiden", "BidenUkraineScandal", "DumpTrump", "NeverTrump", "VoteRed", "VoteBlue"]

num_tweets = 1000

# %%
df = pd.DataFrame()
for word in keywords:
    df = df.append(pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
        '{} near:"Moscow" within:1000km lang:en since:2020-11-01 until:2020-11-30'.format(word)).get_items(), 100))) #[["user", "content", "url", "date", "replyCount", "retweetCount", "likeCount", "mentionedUsers"]]

df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/GladimhereP/status/1326579...
# 1  https://twitter.com/alwaysbeemagic1/status/132...
# 2  https://twitter.com/EliTweetin/status/13244221...
# 3  https://twitter.com/juhainasakhr/status/132411...
# 4  https://twitter.com/assadalia2/status/13240603...
#
#                        date  \
# 0 2020-11-11 17:37:47+00:00
# 1 2020-11-06 13:21:32+00:00
# 2 2020-11-05 18:43:41+00:00
# 3 2020-11-04 22:16:21+00:00
# 4 2020-11-04 18:46:07+00:00
#
#                                              content  \
# 0  @LaraLeaTrump I gave Big Money Rubles to #Trum...
# 1  I wanna have same audacity as Democrats in thi...
# 2  How can anyone not vote for you ! This is epic...
# 3  It's funny how Lebanese people be teaching Ame...
# 4  This is how elections done in USA\n#Biden\n#Tr...
#
#                                      renderedContent                   id  \
# ...

# %%
df.shape
# Out:
# (1857, 21)

# %%
df[["user", "content", "url", "date", "replyCount", "retweetCount", "likeCount", "mentionedUsers"]].to_csv('snscrape_Russia.csv', index = False)
